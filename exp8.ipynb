# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt

start = dt.datetime(2020,4,1)
end = dt.datetime(2023,4,1)

data = yf.download("GOOGL", start=start, end=end)

print(data.head())

close_price = data[['Close']]

dataset = close_price.values

dataset = dataset.reshape(-1,1)

print(dataset.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker          GOOGL      GOOGL      GOOGL      GOOGL     GOOGL
# Date
# 2020-04-01  54.691765  56.047522  54.264493  55.778555  51970000
# 2020-04-02  55.432671  55.717517  54.246632  54.587555  56410000
# 2020-04-03  54.225285  55.520003  53.350895  55.317534  51374000
# 2020-04-06  58.715866  59.091030  55.828184  56.225186  63320000
# 2020-04-07  58.684589  60.581262  58.421081  60.394172  61620000
# (756, 1)
